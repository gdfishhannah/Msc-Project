# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import gc
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import time

# %%
class time_est():
    def __init__(self, total_len):
        self.t_start = time.time()
        self.total_len = total_len
        self.count = 0
        self.t_ref = time.time()
    
    def check(self,no_of_check=1,info=""):
        self.count += no_of_check
        if time.time() - self.t_ref > 1:
            t_used = time.time() - self.t_start
            t_total = t_used * self.total_len / self.count
            t_remain = t_total - t_used
            process_bar = "|"
            for i in range(40):
                if (i/40) < (self.count/self.total_len):
                    process_bar += "█"
                else:
                    process_bar += " "
            process_bar += "|"
            print("\r" + (str(info) + "  {:.2f}% ({}/{})\t".format(self.count * 100/self.total_len, self.count,self.total_len)) + str(process_bar).ljust(45) + "Used: {:02.0f}:{:02.0f}:{:02.0f}".format(int(t_used/3600), int(t_used/60)%60, t_used % 60).ljust(16) + "ETA: {:02.0f}:{:02.0f}:{:02.0f}".format(int(t_remain/3600), int(t_remain/60)%60, t_remain % 60),end="")
            self.t_ref = time.time()
        if self.count == self.total_len:
            t_used = time.time() - self.t_start
            print("\r" + str(info) + "  Finished in " +"{:02.0f}:{:02.0f}:{:02.0f}".format(int(t_used/3600), int(t_used/60)%60, t_used % 60).ljust(100))

# %%
header = [
 'mobile',
 'isrc',
 'upc',
 'artist_name',
 'customer_id',
 'postal_code',
 'access',
 'gender',
 'birth_year',
 'region_code',
 'financial_product',
 'user_product_type',
 'stream_length',
 'stream_source_uri',
 'stream_device',
 'stream_os',
 'track_uri']

# %%
import os
all_file = os.listdir('artist_mar/')

# %%
import sys

# %%
# need to be split into batches
import math
batch = 100
batch_size = math.ceil(len(all_file)/batch)
# index = 0
# for i in range(batch):
#     files = all_file[index:index+batch_size]
batch_size
# Out:
# 251

# %%
all_file[:3]
# Out:
# ['Marco di Mauro.txt',
#  '#1 Club Hits 2008 - Best Of Dance, House, Electro, Trance & Techno (New Edition).txt',
#  '#1 Club Hits 2010 - Best Of Dance & Techno (50 Tracks!).txt']

# %%
large_name = []
est_1 = time_est(batch)
index = 0
count = 0
for i in range(batch):
    files = all_file[i*batch_size:(i+1)*batch_size]
#     count+=(len(files))
    for f in files:
        count+=1
    #     print(f)
    #     try:
        if os.path.getsize('artist_mar/'+f) < 1000000000:
            df = pd.read_csv('artist_mar/'+f,names = header,low_memory=False)
            df = (df[df['stream_length']>=100])
            new_df = pd.DataFrame()

            new_df['customer_id'] = df['customer_id']
            new_df['postal_code'] = df['postal_code']
            new_df['region_code'] = df['region_code']

            df = 0

            location = new_df['region_code'].unique()
            est = time_est(len(location))
            counts = []
            customer = []
            for j in location:
            #     len(new[new[i]])
                if j != 'nan':
                    counts.append(len(new_df[new_df['region_code']==j]['customer_id'].unique()))
                    customer.append(list(new_df[new_df['region_code']==j]['customer_id'].unique()))
            #     break
            # for i in customer:
            #     new[new['customer_id']==i]['region_code']
            #     location.append(new[new['customer_id']==i]['region_code'].iloc[0])
        #             est.check()

            rank = pd.DataFrame()
            rank['region_code'] = location
            rank['loyalty'] = counts
            rank['customer'] = customer
            if len(rank) > 1:
                rank.to_csv('mar/'+f,index = False)
        #         print(f)
        #     except FileNotFoundError:
    #             warning_name.append(f)
    est_1.check()
#     break
# Out:
#   Finished in 02:16:37

# %%
count
# Out:
# 25079

# %%
mar = os.listdir('mar/')

# %%
len(mar)
# Out:
# 380

# %%
list(set(mar)^set(all_file))
# Out:
# ['楊培安.txt',
#  'Paul Rodgers and Friends.txt',
#  'Mago De Oz.txt',
#  'Sylvain Armand.txt',
#  'Guy Clark.txt',
#  'Pinpoint.txt',
#  'Amiel.txt',
#  'Jordi Savall.txt',
#  'Vanilla Sky Soundtrack.txt',
#  'Performance - Original Motion Picture Soundtrack.txt',
#  'Nora Brockstedt.txt',
#  'Rio 2.txt',
#  'P.O.S.txt',
#  'Juha Tapio.txt',
#  'Jazz-Horch-Ester.txt',
#  'Ultra.txt',
#  'Walter Alder.txt',
#  'Asian Dub Foundation.txt',
#  'The Fallout Trust.txt',
#  'Pena Branca and Xavantinho.txt',
#  "The B-52's.txt",
#  'Delilah.txt',
#  'Lesser Key.txt',
#  'James Ingram.txt',
#  'The Musicians of Swanne Alley.txt',
#  'Sinclair.txt',
#  'Joana Machado.txt',
#  'Ya Ho Wa 13.txt',
#  'Eilert Pilarm.txt',
#  'Darkman.txt',
#  'Registrated.txt',
#  'Maxim Vengerov, Mstislav Rostropovich, London Symphony Orchestra.txt',
#  'B Rich.txt',
#  'Frida Amundsen.txt',
#  'Favorite Country Duets.txt',
#  'Helmut & die Dominos.txt',
#  'Rasmus Faber.txt',
#  'NRBQ.txt',
#  'Glenn Jones.txt',
#  'Puff Daddy.txt',
#  'Plush.txt',
#  'Kvelertak.txt',
#  'Vivica Genaux.txt',
#  'Ricky Skaggs.txt',
#  'Charles Feelgood.txt',
#  'Harry Chapin.txt',
#  'DNM feat. Jade.txt',
#  'Louis Armstrong.txt',
#  'Eero ja Jussi & The Boys.txt',
#  'Gianluca Motta, Dr. Space.txt',
#  'Vijay.txt',
#  'Aphex Twin.txt',
#  'Nueva Etica.txt',
#  'Keisha White - WSM UK (7921).txt',
#  'Harry Romero.txt',
#  "Sheila's Little Sister.txt",
#  'Johnny Sea.txt',
#  'Kajsa Grytt.txt',
#  'Robag Wruhme.txt',
#  "St. Elmo's Fire.txt",
#  'Claude Deuce.txt',
#  'Maxima FM Winner DJ.txt',
#  'Percumania.txt',
#  'Paloma San Basilio.txt',
#  'SLAYER.txt',
#  'Jochen Rueckert.txt',
#  'Acoustic Café.txt',
#  'Amen Brothers & The Black Messiah.txt',
#  'Anna Hanski.txt',
#  'Sôber.txt',
#  'Marcelo Vak.txt',
#  'D.P.M..txt',
#  'Sofa.txt',
#  'Orchester J. C. Camet.txt',
#  'Saille.txt',
#  'Jimmy Raney.txt',
#  'Spirit of the West.txt',
#  'Jovari Ensemble.txt',
#  'Riccardo Chailly.txt',
#  'Bad Luck.txt',
#  'Eric Costa.txt',
#  'Tal.txt',
#  'Rokia Traoré.txt',
#  'Dr. Didg.txt',
#  'Soul Vision.txt',
#  'Amine.txt',
#  'Moura Lympany.txt',
#  'Sid Savant.txt',
#  'Soundtrack.txt',
#  'Lars Kilevold.txt',
#  'Amon Duul II.txt',
#  'Nat King Cole.txt',
#  'Marie Soeur Keyrouz.txt',
#  'Atomic.txt',
#  'Eliades Ochoa.txt',
#  'Wir sind Spitze.txt',
#  'INCANTATION.txt',
#  '3Simoa Allstars.txt',
#  'Lady And Bird.txt',
#  'Emanuele Inglese.txt',
#  'Jimmy Hamilton And His Orchestra.txt',
#  'David Tainton.txt',
#  'Voodoo Buddhas.txt',
#  'We Came As Romans.txt',
#  'Rahsaan Roland Kirk.txt',
#  'Benny Hester.txt',
#  'Kiprich.txt',
#  'Roland Darquoy.txt',
#  'Tunnel Alliance.txt',
#  'Antony & The Johnsons.txt',
#  'Yoav.txt',
#  'Skillet.txt',
#  'Nouvelle Vague.txt',
#  'Jose M..txt',
#  'Isabell Münsch.txt',
#  'Fausto Leali.txt',
#  'Sanchez.txt',
#  'Sound Effects.txt',
#  'Blauw Associates.txt',
#  'C Fontaine.txt',
#  'The Red West.txt',
#  'Pugh Rogefeldt.txt',
#  'Wyman.txt',
#  'Tsai Chin.txt',
#  'Uffe Börjesson.txt',
#  'Heidi Montag.txt',
#  'JP Candela & Submission DJ.txt',
#  'Mike Kosa.txt',
#  'Elektronique.txt',
#  'Andrea Chudak, Lidiya Naumova.txt',
#  'I LOVE MAKONNEN.txt',
#  'Matthias Tanzmann.txt',
#  'Ramin Djawadi.txt',
#  'Gummo.txt',
#  'Sara MacDonald.txt',
#  'Laurindo Almeida.txt',
#  'Gilbert Kalish.txt',
#  'Ecos de las Marismas.txt',
#  'Rude Boys.txt',
#  'OPB.txt',
#  'Pavel Dobes.txt',
#  'Webb Wilder.txt',
#  'Meat Puppets.txt',
#  'Miriam Bryant.txt',
#  'Nolan.txt',
#  'Gualberto y Agujetas.txt',
#  'Micken & Freebird.txt',
#  'Suso Vaamonde.txt',
#  'The Flamingos.txt',
#  'T. Love.txt',
#  'Victor Magan.txt',
#  'Azriel.txt',
#  'Moritz Netenjakob.txt',
#  'Naxsy.txt',
#  'Sweet Bitter Blues.txt',
#  'Neville Marriner.txt',
#  'Back Street Crawler.txt',
#  'Base Unique.txt',
#  'Rafael Frühbeck de Burgos.txt',
#  'The Mighty Diamonds.txt',
#  'Niki Reiser.txt',
#  'Hetane.txt',
#  "Gilbert O'Sullivan.txt",
#  'Deep Zone featuring Ceybil Jefferies.txt',
#  '曾路德.txt',
#  'Nena.txt',
#  'Steve Harley & Cockney Rebel.txt',
#  'Nina De Los Peines.txt',
#  'Sid Brown.txt',
#  'Ramasjang Mysteriet.txt',
#  'Gary Moore.txt',
#  'Baracuda.txt',
#  'Antonio de Pinto.txt',
#  'TRX One.txt',
#  'Diamond Project.txt',
#  'The D.O.C..txt',
#  'Hazmat Modine.txt',
#  'Renaud Capuçon.txt',
#  'Classified.txt',
#  'Lars Haavard Haugen.txt',
#  'Dick Rosmini.txt',
#  'Mystical Fullmoon.txt',
#  'Kasalla.txt',
#  'The Jeremy Spencer Band.txt',
#  'Caro Obieglo & Andreas Obieglo.txt',
#  'Marie Meimberg.txt',
#  'Jimmy Greene.txt',
#  'Will Bailey.txt',
#  'Hamburger Ratsmusik.txt',
#  'Olga Tañon.txt',
#  'HeroTV.txt',
#  'Pino Donaggio.txt',
#  'João Lucas.txt',
#  'Marion Raven.txt',
#  'Kirsten og Søren.txt',
#  'Undercover S.K.A..txt',
#  'Nusrat Fateh Ali Khan.txt',
#  'David Zaizar.txt',
#  'Juan Magan, Victor Magan and Josepo feat. Lisa Rose.txt',
#  'The Neon Philharmonic.txt',
#  'Switchfoot.txt',
#  'Cicero.txt',
#  'Nina Gordon.txt',
#  'Soulectrique.txt',
#  'Mario.txt',
#  'Grace.txt',
#  'Sweet November Soundtrack.txt',
#  'Werner Jacob.txt',
#  'Rupert Luck, Matthew Rickard.txt',
#  'Manyou.txt',
#  'Steve Tyrell.txt',
#  'Jornada del Sol.txt',
#  'Nelson Ned.txt',
#  'Die City Preachers.txt',
#  'Steve Reich with Michael Tilson Thomas and the London Symphony Orch..txt',
#  'La Pandilla.txt',
#  'Heart & Soul.txt',
#  'Jori.txt',
#  'Belinda Carlisle.txt',
#  'Shocking Pinks.txt',
#  'Stacy.txt',
#  'Romeos Erben & Nelly Sander.txt',
#  'Morrigans.txt',
#  'Sideburner.txt',
#  'Crown The Empire.txt',
#  'Elisabeth Leonskaja.txt',
#  'Illicit.txt',
#  'The Winkies.txt',
#  'M..txt',
#  'Andrew Rudin.txt',
#  'Tokio.txt',
#  'Katrin Wiegand.txt',
#  'Joseph LoDuca.txt',
#  'The Dad Horse Experience.txt',
#  'Rigu.txt',
#  'Pistones.txt',
#  'Troop.txt',
#  'Phillip Pickett With Richard Thompson.txt',
#  'We Butter The Bread With Butter.txt',
#  'Drop the Subject.txt',
#  'Rae & Christian.txt',
#  'Django Django.txt',
#  'Angela Wunderlich.txt',
#  'Ray Charles.txt',
#  'Static-X.txt',
#  'New Symphony Orchestra of London, Bamberger Symphoniker, RCA Victor Symphony Orchestra.txt',
#  'Slovak Philharmonic Orchestra, Kammerorchester Conrad von der Goltz, Libor Pesek.txt',
#  'Bulgarian Voices Angelite.txt',
#  'Jaakko and Pekka Kuusisto.txt',
#  'Sister2sister.txt',
#  'Varry Brava.txt',
#  'Tilburi.txt',
#  'Les Amis de Selim Aissel.txt',
#  'CSTVT.txt',
#  'Zuat-zu.txt',
#  'Kimberley Rew.txt',
#  'Biohazard.txt',
#  'East 17.txt',
#  'Party Animals.txt',
#  'Jonny Lang.txt',
#  'Diana Ross.txt',
#  'Defected In The House Ibiza 2013.txt',
#  'Martin Stephani & Philharmonia Hungarica.txt',
#  'Christo Jota.txt',
#  'The Pusher.txt',
#  'Steeleye Span.txt',
#  '唐素琪.txt',
#  'Michael Fall & DJ J-Nice.txt',
#  'E-Culture.txt',
#  'Ginny Owens.txt',
#  "Booker T. & The MG's.txt",
#  'Kini Ferrando.txt',
#  'Robert Folk.txt',
#  'Maite Perroni.txt',
#  'CLS & Wax feat. SQBass.txt',
#  'Crescent Moon Is In Big Trouble.txt',
#  'Anders Johansson.txt',
#  'Codex.txt',
#  'Arturo Sandoval.txt',
#  'Captain Twang And His Rhythm Cat.txt',
#  'Fabo.txt',
#  'Dario Domingues.txt',
#  'Lorena C.txt',
#  'Archie Shepp - Horace Parlan Duo.txt',
#  'Barbara Keith.txt',
#  'Asterix.txt',
#  'Alvin And The Chipmunks.txt',
#  'Barbara Borden, Suzie Le Blanc, Päivi Järviö, John Potter, Douglas Nasrawi, Cesare Righetti, Harry van der Kamp, Stephen Stubbs & Tragicomedia.txt',
#  'Saian Supa Crew.txt',
#  'Kevin Mahogany.txt',
#  'Sirens Sister.txt',
#  'Dale Chambers.txt',
#  'I Am King.txt',
#  'Lars Lilholt.txt',
#  'Sticky.txt',
#  'Dantiez Saunderson.txt',
#  'Katharine Mehrling.txt',
#  'Pino Daniele.txt',
#  'Shout Out Out Out Out.txt',
#  'Zipera.txt',
#  'Feltmann.txt',
#  'Lazy Lester.txt',
#  'Electric Blues Duo.txt',
#  'Patrice.txt',
#  'Pezet.txt',
#  'Petal.txt',
#  'Course Of Action.txt',
#  'Internacional Carro Show.txt',
#  'Climax Golden Twins.txt',
#  'Biscaya.txt',
#  'The Goo Goo Dolls.txt',
#  'Dwight Yoakam - South Of Heaven, West Of Hell Soundtrack.txt',
#  'Klaus Schønning.txt',
#  'Charlie Dore.txt',
#  'Funeral For A Friend.txt',
#  'Zaa feat. Aneym.txt',
#  'Novastar.txt',
#  'Tanja Vähäsarja.txt',
#  'Brian May.txt',
#  'Inglese & Marini.txt',
#  'Cruz Martinez presenta Los Super Reyes.txt',
#  'Pernett.txt',
#  'Britny Fox.txt',
#  'Dylan Donkin.txt',
#  'Dyango.txt',
#  'The Ultimate Most Relaxing Music for Strings In The Universe.txt',
#  'Morten Harket.txt',
#  'Sha-Boom.txt',
#  'Defected In The House Miami 2013.txt',
#  'Arbeit.txt',
#  'Kashief Lindo.txt',
#  'Highmaker.txt',
#  'Joakim.txt',
#  'The Monks.txt',
#  'Taipan.txt',
#  'Kindergarten.txt',
#  'Lady XTC.txt',
#  'Herbert von Karajan.txt',
#  'Mark Jackus.txt',
#  'jj.txt',
#  'Emily & The Boys.txt',
#  'Wade Fruge.txt',
#  'Juan Darthés.txt',
#  'Sebastien Benett.txt',
#  'Freddie Roulette.txt',
#  'Shirley Scott.txt',
#  'John F. & Die Gropiuslerchen.txt',
#  'John Markyz.txt',
#  'Albano Carrisi.txt',
#  'Michel Birbaek.txt',
#  'Mustard Plug.txt',
#  'Revolvr, DJ Red & Scotty Boy.txt',
#  'Win Kowa.txt',
#  'Deep Insight.txt',
#  'DJ Antoine.txt',
#  'Alborosie.txt',
#  'Joe Turner.txt',
#  'Xandra Hag.txt',
#  'Bonkers.txt',
#  'Selah Sue.txt',
#  'Solonen & Kosola.txt',
#  'Richard Hawley.txt',
#  'Elliott Carter.txt',
#  'Brendan Croskerry.txt',
#  'Vladimir.txt',
#  'CXY.txt',
#  'Frida Sundemo.txt',
#  'Yo-Yo.txt',
#  'Chad Mitchell.txt',
#  'Kiernan McMullan.txt',
#  'Del Faro.txt',
#  'Sandy Wagner.txt',
#  'Galago.txt',
#  'Angry.txt',
#  'Sasha Lopez.txt',
#  'Rex Allen, Jr..txt',
#  'FRANK T.txt',
#  'Chris Youlden.txt',
#  'S&H Project.txt',
#  'DJ Karizma.txt',
#  'Run Hide Survive.txt',
#  'Constantin Silvestri.txt',
#  'Heinz Rühmann.txt',
#  'Arion.txt',
#  'Chris Braide.txt',
#  'Pearl Harbor - Original Motion Picture Soundtrack.txt',
#  'Dov Davidoff.txt',
#  'House 2 House.txt',
#  'Fito y Fitipaldis.txt',
#  'Tegan And Sara.txt',
#  'Carl Orff.txt',
#  'Pat Krimson.txt',
#  'Dave Grusin.txt',
#  'Mary Halvorson.txt',
#  'MARK KING.txt',
#  'Ushuaia Ibiza The Album - The Unexpected Session.txt',
#  "Lille John With The Rockin' Jupiters.txt",
#  'Christian Zimmermann.txt',
#  'Transform.txt',
#  'Boney Fields.txt',
#  'Juhani Aaltonen.txt',
#  'Pure Love Remixed.txt',
#  'The Dawn.txt',
#  'Canto Nono.txt',
#  'ERROL BROWN.txt',
#  'Heiko Laux.txt',
#  'Ramon Tapia.txt',
#  'O H Krill.txt',
#  'Toftgard.txt',
#  'Shantel & Areti Ketime.txt',
#  'Starfucker & Champagne Champagne.txt',
#  'Vato Gonzalez.txt',
#  'Shelter.txt',
#  'Chinese Flash Mob.txt',
#  'Lesiem.txt',
#  'Peter Schmalfuss.txt',
#  'The Bangles.txt',
#  'AnarchyX.txt',
#  'Fortitude.txt',
#  'Waxwings.txt',
#  'John Berkhout.txt',
#  'Freaky Flow.txt',
#  'De Schellebellen.txt',
#  'Derek Watkins.txt',
#  'Jamie Antonelli.txt',
#  'Stephen Sondheim.txt',
#  'Thinkadelic.txt',
#  'Sevasti.txt',
#  'The Friday Club.txt',
#  'Joan Baptista Humet.txt',
#  'Maroon.txt',
#  'Clor.txt',
#  'TUNER.txt',
#  'Jerry Butler.txt',
#  'DJ Le Roi.txt',
#  'Crawlspace.txt',
#  'Brothers From Another Planet.txt',
#  'Manfred Krug & Charles Brauer.txt',
#  'Assia.txt',
#  'Freedom Hawk.txt',
#  'Die Another Day Soundtrack.txt',
#  'Indie Jones.txt',
#  'Vadim Repin, Kent Nagano & Hallé Orchestra.txt',
#  'Morten Abel.txt',
#  'The Flatlanders.txt',
#  'Jerry Williams.txt',
#  'UpTop.txt',
#  'Them Idiots.txt',
#  'Bolland, C.J..txt',
#  'Duo Villarceaux.txt',
#  'Melody Club.txt',
#  'A-Alikes.txt',
#  'Michael Morgan.txt',
#  'Katja.txt',
#  'Raymond Devos.txt',
#  'Sindicato Del Crimen.txt',
#  'Separations.txt',
#  '123 Soul.txt',
#  'FLEX.txt',
#  'The Kiki Dee Band.txt',
#  'Jackson Singers.txt',
#  'DJ Randall Jones.txt',
#  'Los Antesdea Yesterday.txt',
#  'Rozwell Kid.txt',
#  'Die Zipfelbuben.txt',
#  'The Subliminals.txt',
#  'Hundhimlen.txt',
#  'Panthers.txt',
#  'Marco Angelini.txt',
#  'VERIDIA.txt',
#  'Amede Ardoin.txt',
#  'Hombres G.txt',
#  'Jean-Claude Annoux.txt',
#  'Tours.txt',
#  'Alice Coltrane.txt',
#  'Bim.txt',
#  'Anna Mailian.txt',
#  'Riddim Driven: Dancehall Rock.txt',
#  'M. Abdul Gani.txt',
#  'Randi Laubek.txt',
#  'Flatpocket.txt',
#  'Nathan Abshire & the Pine Grove Boys.txt',
#  'Boogie Boys.txt',
#  'Conchita Piquer.txt',
#  'Sonia Madoc.txt',
#  'Mz Bratt.txt',
#  'the GazettE.txt',
#  'David Penn.txt',
#  'Gabriel Szternsztejn Cuarteto.txt',
#  'Pernilla Andersson.txt',
#  'Cabaret Voltaire.txt',
#  'Ronald Smith.txt',
#  'Garbo.txt',
#  'Rapsta.txt',
#  'Tonio K..txt',
#  'Laksham Joseph De Saram, Rachel Portman.txt',
#  'Orlando di Lasso Ensemble Hannover.txt',
#  'Jimmy Barnatan.txt',
#  'DeLeon Richards.txt',
#  'John Hammond Jr..txt',
#  'Milow.txt',
#  'The Hodges Brothers.txt',
#  'Sufjan Stevens.txt',
#  'Paul Tortelier.txt',
#  'Lova Sönnerbo.txt',
#  'Lord Finesse.txt',
#  'Miranda!.txt',
#  'Hayley Mills.txt',
#  'Phuture Doom.txt',
#  'General Surgery.txt',
#  'Song Thai.txt',
#  'The Lonely H.txt',
#  'Mark Mancina.txt',
#  'The Cars.txt',
#  'East & Young.txt',
#  'Iannis Xenakis.txt',
#  'Jette Torp.txt',
#  'Sonny Simmons.txt',
#  'Carla Bruni.txt',
#  'Love.txt',
#  'Bill Coleman.txt',
#  'Lundaland.txt',
#  'Odetta.txt',
#  'Termplex.txt',
#  'Otargos.txt',
#  'Piccadilly Six.txt',
#  "Orchestra Sinfonica Dell'Arte, Guiseppe Menarelli.txt",
#  'Piper Records.txt',
#  '棒棒堂.txt',
#  'Frankie Valli & The Four Seasons.txt',
#  'Project Memory.txt',
#  'Benne.txt',
#  'The Pains Of Being Pure At Heart.txt',
#  'Fleetwood Mac.txt',
#  'Rick and Renner.txt',
#  'Mo Mandel.txt',
#  'Mark Trophy And Sonny Wharton.txt',
#  'Hannes Marold.txt',
#  'Pachanga.txt',
#  'Headcrash.txt',
#  'Fernando Velázquez.txt',
#  'Venus Outback.txt',
#  'Pablo Guerrero.txt',
#  'Junior Jazz.txt',
#  'Lewis Black.txt',
#  'Black Art Music.txt',
#  'Copenhagen Classic.txt',
#  'Cubanismo.txt',
#  'Susan Graham & Pierre-Laurent Aimard.txt',
#  'Immortal.txt',
#  'Cañada de la cumbia.txt',
#  'Kamil Strihavka.txt',
#  'Don Ho.txt',
#  'Josh Rouse.txt',
#  'Rojas.txt',
#  'Veit Etzold.txt',
#  'Olli Schulz.txt',
#  'Δημήτρης Κοργιαλάς.txt',
#  'Shane Brown.txt',
#  'Markus Psotta.txt',
#  'Supernatural.txt',
#  'Kyova.txt',
#  'Johnny Crawford.txt',
#  'Jutty Ranx.txt',
#  'Shirley Horn.txt',
#  'Luke Meyers.txt',
#  'Dune Rats.txt',
#  'Tanita.txt',
#  'The Charles River Valley Boys.txt',
#  'Billie Joe.txt',
#  'Rebelski.txt',
#  're:lounge.txt',
#  'Mark Harris.txt',
#  'Royal Bliss.txt',
#  'Marsal Ventura, Jordi Veliz, Surrender Djs.txt',
#  'Gorchitza.txt',
#  'Manudub.txt',
#  'Los Galvan.txt',
#  'Poison Pen.txt',
#  'The Flesh Eaters.txt',
#  'Rodney Perry.txt',
#  'David Spade.txt',
#  'Hudba Praha.txt',
#  'Count Bass D.txt',
#  'Arja Koriseva.txt',
#  'Afterworkmeditation.txt',
#  'Celso Piña y su Ronda Bogotá.txt',
#  'Groove Armada.txt',
#  'Wipe The Needle.txt',
#  'Patti Page.txt',
#  'Kim Larsen & Kjukken.txt',
#  'Brooks Wheelan.txt',
#  'RL Grime.txt',
#  'Espectaculares de Lola Beltran y Enriqueta Jimenez "La Prieta Linda".txt',
#  '官恩娜.txt',
#  'Buzzhorn.txt',
#  'Marc Shaiman.txt',
#  'Chris Wilson.txt',
#  'Sidecars.txt',
#  'Weimarer Barock-Ensemble.txt',
#  'MSTRKRFT.txt',
#  'Ingrid Krauß.txt',
#  "Orchestra da Camera Dell'Arte, Luigi Zanetti.txt",
#  'Broadcast.txt',
#  'Bobby King.txt',
#  'Dixie Witch.txt',
#  'Micke Hagström.txt',
#  'Jah Cure.txt',
#  'Waka Flocka Flame.txt',
#  'Daniel Bryer.txt',
#  'Al Fatz.txt',
#  'Inflabluntahz.txt',
#  'Rev. Louis Overstreet.txt',
#  'Hans Koller, Attila Zoller, Roland Hanna.txt',
#  'Artango.txt',
#  'Alexandre Tharaud.txt',
#  'Drehmoment.txt',
#  'Grupo Fantasma.txt',
#  'Harem Scarem.txt',
#  'Vera Heindel.txt',
#  'Jakob Hellman.txt',
#  'Suffocation.txt',
#  "Rod Mason's Jazz Band.txt",
#  'Beata Bednarz.txt',
#  'Beverly McClellan.txt',
#  'Gudrun Likar.txt',
#  'No Ice Cream Sound.txt',
#  'Helga Reichel, Hans Kollmannsberger und die Loisachtaler Musi.txt',
#  'Put Your Hands In The Air.txt',
#  'Zinner.txt',
#  'Lost & Found EP.txt',
#  'Sangit.txt',
#  'Week End Millionnaire.txt',
#  'Jim E. Carter.txt',
#  'PERFUME SOUND.txt',
#  'Rebecca Stella.txt',
#  'tofubeats.txt',
#  'Formation Soul.txt',
#  'Man Bai.txt',
#  'Amnestiet.txt',
#  'Gabriel Yared, Stéphane Moucha.txt',
#  'Paolo Simoni.txt',
#  'Akhenaton.txt',
#  'Nik Bärtsch.txt',
#  'Roach Motel.txt',
#  'Bushman.txt',
#  'Danne Stråhed.txt',
#  'Fred Adams And His Romantic Accordion Sound.txt',
#  'TANIA DE SOUSA.txt',
#  'Proktah, Dementia & NME Click.txt',
#  'Root Boy Slim & The Sex Change Band.txt',
#  'Outrowz.txt',
#  'Massimo De Bernart.txt',
#  'Wayne Wonder.txt',
#  'Les petits Chanteurs de Saint-Marc RECITAL.txt',
#  'เต๋า เศรษฐพงศ์.txt',
#  "The World's Greatest Jazz Band Of Yank Lawson & Bob Haggart.txt",
#  'Clarence Carter.txt',
#  'Paco Sery.txt',
#  'Shur-i-kan.txt',
#  'Sergio Makaroff.txt',
#  'Tanja Kinkel.txt',
#  'Shirley Murdock.txt',
#  'Adam Strug.txt',
#  'Shy Glizzy.txt',
#  'Nicole Renee Harris.txt',
#  '2Shine.txt',
#  'Mischa Maisky.txt',
#  'J-Shin.txt',
#  'Colorbox.txt',
#  'Corale Universitaria "Lorenzo Valla".txt',
#  'Avi Elman & Danny J feat. Nuwella.txt',
#  'Make Some Noise: The Amnesty International Campaign To Save Darfur.txt',
#  'Burkard Schmidl.txt',
#  'Jodi Picoult.txt',
#  'Beepop.txt',
#  'J.K. feat Dave Weckl.txt',
#  'John Stoddart.txt',
#  'Ribs.txt',
#  'Red Box.txt',
#  'Vern Gosdin.txt',
#  'Tomas Jirku, Robin Judge.txt',
#  'Hans Walter Lorang.txt',
#  'Pascal Junior.txt',
#  'Turbo.txt',
#  'Conor Maynard.txt',
#  "Jimmy Black's Dixie-Band.txt",
#  'Chung Trio.txt',
#  'Antoine Montana.txt',
#  'Bruce Bouillet.txt',
#  'Norrisman.txt',
#  'Nino Tempo & April Stevens.txt',
#  'Cibo Matto.txt',
#  'Renaissance.txt',
#  'The Disco Boys feat. Midge Ure.txt',
#  'Pro Cantione Antiqua.txt',
#  'G. Dep.txt',
#  'Nunca.txt',
#  'The Axel Boys Quartet.txt',
#  '張雨生.txt',
#  'Almir Sater.txt',
#  'Riddim Driven: Rah Rah.txt',
#  'Kris Tinkle.txt',
#  'Bla Bla.txt',
#  'Golf.txt',
#  'M. J. Arlidge.txt',
#  'Bronski Beat.txt',
#  'Sir Alexander Gibson.txt',
#  'Michael Jackson Tribute.txt',
#  'Bernie Leadon.txt',
#  'Stephen Duffy.txt',
#  'Lasse Mårtenson.txt',
#  'Handful of Hate.txt',
#  'Deville.txt',
#  'David Herrero.txt',
#  'LeSonic.txt',
#  'Patrick Watson.txt',
#  'Charles Wright & The Watts 103rd Street Rhythm Band.txt',
#  'Matt Schofield.txt',
#  'Aryay.txt',
#  'Samir & Viktor.txt',
#  'Maná.txt',
#  'Domain.txt',
#  'Έλλη Πασπαλά.txt',
#  'Roger S.txt',
#  'Long Distance Calling.txt',
#  'Kyle Cease.txt',
#  'Regina Carter.txt',
#  'Leticia Sabater.txt',
#  'Los Ángeles.txt',
#  'EMF.txt',
#  'Thomas Anders.txt',
#  'Antonio Pinto, Ed Cortes.txt',
#  'Vocoder.txt',
#  'Lottergirls.txt',
#  'Hijjaz.txt',
#  'Eva Ibbotson.txt',
#  'Defected Presents Noir In The House Album Sampler.txt',
#  'Max Vertigo & SevenEver.txt',
#  'Johanna Kurkela.txt',
#  'Benny Goodman.txt',
#  'Twenty One Pilots.txt',
#  'Lawrence "Black" Ardoin.txt',
#  'Sha Li Mar.txt',
#  'Marshall Crenshaw.txt',
#  'Thomas Koppe.txt',
#  'Tätärä.txt',
#  'Tage Östs Fyrklang.txt',
#  'Heike Schäfer.txt',
#  'Hugh Dillon.txt',
#  'Stooshe.txt',
#  "Adam & die Micky's.txt",
#  'Erkan Aki.txt',
#  "Daddy's Groove and Little Mark.txt",
#  'Chloë Hanslip.txt',
#  'Joe Nebula.txt',
#  'Johannes Cernota.txt',
#  'Norm MacDonald.txt',
#  'Morislaw Czyzykiewicz.txt',
#  'Meshell Ndegeocello.txt',
#  'Laidback Luke.txt',
#  'The Vision.txt',
#  'Maurice Da Vido.txt',
#  'Muzzle.txt',
#  'Serk.txt',
#  'Big Pig.txt',
#  'Afro Cube.txt',
#  'Ian Anderson.txt',
#  'Elbicho.txt',
#  'Banda de musica de la agrupacion de Infanteria de Marina de Madrid.txt',
#  'Berry Orchestra Lipman.txt',
#  'Lewis Watson.txt',
#  'Chill Brazil.txt',
#  'Heinz Sauer, Bob Degen.txt',
#  'Understand.txt',
#  'Madredeus & A Banda Cósmica.txt',
#  'Nikolaus Harnoncourt & Royal Concertgebouw Orchestra.txt',
#  'Sergent Garcia.txt',
#  'Kenny Wayne Shepherd.txt',
#  'Killswitch Engage.txt',
#  'Burn Down Rome.txt',
#  "Leo Tolstoy's Anna Karenina.txt",
#  'Tandem Sky.txt',
#  'Artist Unknown.txt',
#  'Beverley Knight.txt',
#  'Dama.txt',
#  'Ian Pooley.txt',
#  'Badische Staatskapelle Karlsruhe, Guenter Neuhold, Emma Schmidt.txt',
#  'เสือโคร่ง.txt',
#  'Theodore Shapiro and Lee Mars.txt',
#  'Cliff Jackson.txt',
#  'Lionel Hampton.txt',
#  'Danny Kroha.txt',
#  'Storyville.txt',
#  'Dreadnaught.txt',
#  'Anita Skorgan.txt',
#  'Natty I.txt',
#  'Re-Touch.txt',
#  'Die jungen Trompeter.txt',
#  'Yuri Temirkanov & St Petersburg Philharmonic Orchestra.txt',
#  'Grand Theft Audio.txt',
#  'Dalorian.txt',
#  'Christian McBride.txt',
#  'Renee Olstead.txt',
#  'LaSelva feat. Charlotte Spink.txt',
#  'David Lloyd Jones.txt',
#  '38th Parallel.txt',
#  'Chor der Metropolitan Opera, Orchester der Metropolitan Opera, Dimitri Mitropoulos.txt',
#  'George Enescu.txt',
#  'The Derailers.txt',
#  'Rune RK.txt',
#  'The Dynamics.txt',
#  'Nu Flavor.txt',
#  'Beatrice Thiriet.txt',
#  'Dope Smugglaz.txt',
#  'Tracer.txt',
#  'Mia Marianne & Per Filip.txt',
#  'Charles Brown.txt',
#  'Ekkohaus.txt',
#  'Dutch Rhythm Combo.txt',
#  'Armando Trovajoli.txt',
#  'Joy Williams.txt',
#  'Chor und Orchester der Deutschen Oper Berlin, Rafael Frühbeck de Burgos.txt',
#  'Million Dollar Quartet.txt',
#  'Sviatoslav Richter, Yuri Bashmet & Orchestra di Padova e del Veneto.txt',
#  'Manuela.txt',
#  'Beautiful Killing Machine.txt',
#  'Louie Corrales.txt',
#  'Das Beste kommt zum Schluss.txt',
#  'Deer Tick.txt',
#  'Roel.txt',
#  'Roustem Saitkoulov.txt',
#  'Summer Grooves.txt',
#  'Gold, Diaz & Young Rebels.txt',
#  'Sherlock Holmes.txt',
#  'Guiseppe Bruno.txt',
#  'Henrik Wager.txt',
#  'Charles Redland.txt',
#  'JoJo.txt',
#  'Edvard Grieg: Klavierkonzert A-Moll.txt',
#  'Juke Boy Bonner.txt',
#  'George Lewis.txt',
#  'Torsten Abrolat, Franziska Diesmann.txt',
#  'Catherine Delasalle.txt',
#  'Andy Williams.txt',
#  'Erik Grip.txt',
#  'Gallows.txt',
#  'Andy Haynes.txt',
#  'Marc Maris vs. Ramone.txt',
#  'Kerri Chandler.txt',
#  "Buddha's Gamblers.txt",
#  'Maxus.txt',
#  'MakSim.txt',
#  'BalkanVision & Mashina.txt',
#  'Piotr Rubik feat. Grzegorz Wilk.txt',
#  'Nezmari.txt',
#  'The Rubinoos.txt',
#  'R3hab.txt',
#  'The Members.txt',
#  'The Echo Friendly.txt',
#  'God Help The Girl.txt',
#  'Sugarfree.txt',
#  'IllSkillz.txt',
#  'Nocturna - La Nuit Magique.txt',
#  'Larry The Cable Guy.txt',
#  'Racine.txt',
#  'Helsinki Philharmonic Orchestra and Espoo Chamber Orchestra.txt',
#  'Aldebert.txt',
#  'Bunbury.txt',
#  'Meg Mac.txt',
#  'Stefan Hussong, Mika Yamada, Julius Berger.txt',
#  'Canzoniere Grecanico Salentino.txt',
#  'Remu.txt',
#  'Donna McElroy.txt',
#  'Danny Bensi, Saunder Jurriaans.txt',
#  'Judy Collins.txt',
#  '金智娟.txt',
#  'Ballyhoo!.txt',
#  'Demba Conta.txt',
#  'David Mitchell.txt',
#  'The Joy Formidable.txt',
#  'TED NUGENT.txt',
#  'A River Runs Through It.txt',
#  'Klimmstein.txt',
#  'Keith Washington.txt',
#  'Bryn Terfel, Andrew Davis, BBC Singers, BBC Symphony Chorus & Orchestra.txt',
#  'Sons Of San Joaquin.txt',
#  'Chris Everheart.txt',
#  'Fretwork.txt',
#  'Sporty Loco.txt',
#  'A Skylit Drive.txt',
#  'Douglas Datwyler.txt',
#  'Heed.txt',
#  'DJ Bobo & Sandra.txt',
#  'Peter Thomas.txt',
#  'I Was A King.txt',
#  'Edu Imbernon & Triumph.txt',
#  'Agepê.txt',
#  'Robert Stolz & Die Wiener Symphoniker.txt',
#  'Neal McCoy.txt',
#  'Gus Black.txt',
#  'Olivier Baumont.txt',
#  'Karo Glazer.txt',
#  'NEEDTOBREATHE.txt',
#  'Doreen Shaffer.txt',
#  'Florent Mothe.txt',
#  'Meic Stevens.txt',
#  'Michael Bublé.txt',
#  'Swinging Funfares.txt',
#  'Michel Corboz & Ensemble Vocal et Instrumental de Lausanne.txt',
#  'Pianissimo.txt',
#  'Frozen Ghost.txt',
#  'Andy J. Forest Band.txt',
#  'The Lazy Lovers.txt',
#  'DJ Groove feat. Rhymes & Prok.txt',
#  'Franky Rizardo.txt',
#  'Guille.txt',
#  'Global Deejays Feat. Rozalla.txt',
#  'Marianne Faithfull.txt',
#  'Paul Robeson.txt',
#  'Estrella Morente.txt',
#  'Melvins.txt',
#  'Babble.txt',
#  'Itzhak Perlman.txt',
#  'La Mona Jimenez.txt',
#  'John Stevens.txt',
#  'Admiral Tibett.txt',
#  'Marburger Bachchor, Hessisches Bach-Kollegium, Wolfram Wehnert.txt',
#  'Nikolaus Harnoncourt, Concentus musicus Wien, Frans Brüggen, Otto Fleischmann, Alice Harnoncourt, Walter Pfeiffer, Peter Schoberwalter, Kurt Theiner, Hermann Rohrer, Horst Fischer, Jürg Schaeftlein, Karl Gruber & Bernhard Klebel.txt',
#  'Chor des Bayerischen Rundfunks, Orchester des Bayerischen Rundfunks, Eugen Jochum.txt',
#  'Babaluga.txt',
#  'Bhonus.txt',
#  'I See Stars.txt',
#  'Kunci.txt',
#  'Heinrich-Isaak-Ensemble.txt',
#  'Lumidee vs. Fatman Scoop.txt',
#  'Flashback.txt',
#  'Dave Stewart & His Rock Fabulous Orchestra.txt',
#  'The Gordons.txt',
#  'Luna Simao.txt',
#  'Goddess of Marriage.txt',
#  'Rick Kills Kid.txt',
#  'Boom Reggae Hits Vol. 4.txt',
#  'O Rappa.txt',
#  'Malgosia Jamrozy.txt',
#  'Knabenchor Hannover, Barockorchester "L\'arco", Heinz Henning.txt',
#  'Slipknot.txt',
#  'Shuanise.txt',
#  'Daishin Kashimoto.txt',
#  'Les Privatiers.txt',
#  'Reggie Stepper.txt',
#  'Blood Diamonds.txt',
#  'The Smiths.txt',
#  'Sr. Javier.txt',
#  'Chaka Kahn.txt',
#  'Sun Domingo.txt',
#  'Marcia Hines.txt',
#  'Javier Logares.txt',
#  'The Specials.txt',
#  'Bloc Party.txt',
#  'Sval.txt',
#  'Jean Sourisse.txt',
#  'Ensemble Discantus.txt',
#  'Marius.txt',
#  'N. B. C. Orchestra, Arturo Toscanini.txt',
#  'At The Drive-In.txt',
#  'Trotwood.txt',
#  'Flotsam & Jetsam.txt',
#  'Kilian Dominguez.txt',
#  'Heartbeat Club.txt',
#  'After The Burial.txt',
#  'Cary Greisch.txt',
#  'Cascade.txt',
#  'Stellar Master Elite.txt',
#  'Christian Falero.txt',
#  'Contrazt.txt',
#  'Lieven.txt',
#  'Rainer Rabus & Friends.txt',
#  'Lele.txt',
#  'November Project.txt',
#  'Raine Maida.txt',
#  'Nu Shooz.txt',
#  'Hitbox Vol.2.txt',
#  'The Advent.txt',
#  'Kotvald a Hlozek.txt',
#  'Witold Malcuzynski.txt',
#  'Sitaram.txt',
#  'Mozart Opera Rock.txt',
#  'Ebola.txt',
#  'Kim Criswell, Yutaka Sado & Orchestre Lamoureux.txt',
#  'Karpatenhund.txt',
#  'Super Grupo Colombia.txt',
#  'Night Terrors Of 1927.txt',
#  'OWSLA Presents EGGNOG.txt',
#  'Susan Graham, Yan Pascal Tortelier & BBC Symphony Orchestra.txt',
#  'Magnus Johansson.txt',
#  'Mentecy.txt',
#  'Maria Lucia.txt',
#  'Big Band de Canarias.txt',
#  'Cori Yarckin.txt',
#  ...]

# %%
['Ed Sheeran.txt', 'Various Artists.txt', 'David Guetta.txt']
