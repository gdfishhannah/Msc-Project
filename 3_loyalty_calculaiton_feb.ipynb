# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import gc
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import time

# %%
class time_est():
    def __init__(self, total_len):
        self.t_start = time.time()
        self.total_len = total_len
        self.count = 0
        self.t_ref = time.time()
    
    def check(self,no_of_check=1,info=""):
        self.count += no_of_check
        if time.time() - self.t_ref > 1:
            t_used = time.time() - self.t_start
            t_total = t_used * self.total_len / self.count
            t_remain = t_total - t_used
            process_bar = "|"
            for i in range(40):
                if (i/40) < (self.count/self.total_len):
                    process_bar += "█"
                else:
                    process_bar += " "
            process_bar += "|"
            print("\r" + (str(info) + "  {:.2f}% ({}/{})\t".format(self.count * 100/self.total_len, self.count,self.total_len)) + str(process_bar).ljust(45) + "Used: {:02.0f}:{:02.0f}:{:02.0f}".format(int(t_used/3600), int(t_used/60)%60, t_used % 60).ljust(16) + "ETA: {:02.0f}:{:02.0f}:{:02.0f}".format(int(t_remain/3600), int(t_remain/60)%60, t_remain % 60),end="")
            self.t_ref = time.time()
        if self.count == self.total_len:
            t_used = time.time() - self.t_start
            print("\r" + str(info) + "  Finished in " +"{:02.0f}:{:02.0f}:{:02.0f}".format(int(t_used/3600), int(t_used/60)%60, t_used % 60).ljust(100))

# %%
header = [
 'mobile',
 'isrc',
 'upc',
 'artist_name',
 'customer_id',
 'postal_code',
 'access',
 'gender',
 'birth_year',
 'region_code',
 'financial_product',
 'user_product_type',
 'stream_length',
 'stream_source_uri',
 'stream_device',
 'stream_os',
 'track_uri']

# %%
import os
all_file = os.listdir('artist_feb/')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-3d3718aa0ce9> in <module>()
#       1 import os
# ----> 2 all_file = os.listdir('artist_feb/')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'artist_feb/'

# %%
len(all_file)
# Out:
# 24600

# %%
# need to be split into batches
import math
batch = 100
batch_size = math.ceil(len(all_file)/batch)
# index = 0
# for i in range(batch):
#     files = all_file[index:index+batch_size]
batch_size
# Out:
# 246

# %%
all_file[:3]
# Out:
# ['Love of Lesbian.txt',
#  '#1 Club Hits 2008 - Best Of Dance, House, Electro, Trance & Techno (New Edition).txt',
#  '&ME.txt']

# %%
large_name = []
est_1 = time_est(batch)
index = 0
count = 0
for i in range(batch):
    files = all_file[i*batch_size:(i+1)*batch_size]
#     count+=(len(files))
    for f in files:
        count+=1
#         print(f)
        
        if os.path.getsize('artist_feb/'+f) < 1000000000:
            df = pd.read_csv('artist_feb/'+f,names = header,low_memory=False)
            try:
                df = (df[df['stream_length']>=100])
            except TypeError:
                    large_name.append(f)
                    continue
            new_df = pd.DataFrame()

            new_df['customer_id'] = df['customer_id']
            new_df['postal_code'] = df['postal_code']
            new_df['region_code'] = df['region_code']

            df = 0

            location = new_df['region_code'].unique()
            est = time_est(len(location))
            counts = []
            customer = []
            for j in location:
            #     len(new[new[i]])
                if j != 'nan':
                    counts.append(len(new_df[new_df['region_code']==j]['customer_id'].unique()))
                    customer.append(list(new_df[new_df['region_code']==j]['customer_id'].unique()))
            #     break
            # for i in customer:
            #     new[new['customer_id']==i]['region_code']
            #     location.append(new[new['customer_id']==i]['region_code'].iloc[0])
        #             est.check()

            rank = pd.DataFrame()
            rank['region_code'] = location
            rank['loyalty'] = counts
            rank['customer'] = customer
            if len(rank) > 1:
                rank.to_csv('feb/'+f,index = False)
            #         print(f)
        else:
            large_name.append(i)
        
    est_1.check()
#     break
# Out:
#   Finished in 02:17:17

# %%
count

# %%
feb = os.listdir('feb/')

# %%
len(feb)

# %%
list(set(feb)^set(all_file))
# Out:
# ['Julio Sosa y Francisco Rotundo.txt',
#  'Amelie.txt',
#  'Onesidezero.txt',
#  'Anis.txt',
#  'Olga Manzano y Manuel Picon.txt',
#  'Fight or Flight.txt',
#  'Sybreed.txt',
#  'Michel Beroff.txt',
#  'Funky Freakz.txt',
#  'Joana Machado.txt',
#  'Jelly Roll Morton.txt',
#  'Lofofora.txt',
#  'Shaver.txt',
#  'Man Bai.txt',
#  '何韻詩.txt',
#  'Unwritten Law.txt',
#  'Gentle Beats.txt',
#  'Julja Beretta.txt',
#  'Lucienne Delyle.txt',
#  'Manickam Yogeswaran.txt',
#  'Eve Brenner.txt',
#  'Geier Sturzflug.txt',
#  'E-Trax.txt',
#  'Zvi Emanuel-Marial, Philip Mayers.txt',
#  'Bonfire.txt',
#  'Rodney Crowell.txt',
#  'No-Man.txt',
#  'Sternblut.txt',
#  'Ryan Amon.txt',
#  'He Is Legend.txt',
#  'The Flying Tigers.txt',
#  'The Sundays.txt',
#  'Peter Wolf.txt',
#  'Habana Abierta.txt',
#  'The Network.txt',
#  'Amanda Stott.txt',
#  'Doobie J feat. Hannah G.txt',
#  'Dara Rolins.txt',
#  'Brasco & El Matador.txt',
#  'Kristy Starling.txt',
#  'Marília Bessy.txt',
#  'The Blues Brothers.txt',
#  'ADK and Thyivya Kalaiselvan.txt',
#  'Galileo.txt',
#  'Tina Dico.txt',
#  'Taito Tikaro & Lydia Sanz.txt',
#  'The Be Good Tanyas.txt',
#  "Maura O'Connell.txt",
#  'Choeur Byzantin de Grèce.txt',
#  'Francesca Battistelli.txt',
#  'Musik der Renaissance fuer Floete und Laute.txt',
#  'Slowakische Staatsphilharmonie.txt',
#  'Colour Haze.txt',
#  'Gräfin Johanna von Deter Püffel.txt',
#  'Martin Best.txt',
#  'Set To Stun.txt',
#  'Worship Tracks.txt',
#  'Angry.txt',
#  'Victor y Diego.txt',
#  'Sharam Jey.txt',
#  'The Rubinoos.txt',
#  'Pulsaar.txt',
#  'Sheila Majid.txt',
#  'Dixie Witch.txt',
#  'TEXTURES.txt',
#  'Sugar & Spice.txt',
#  'Ken Dodd.txt',
#  'NEK.txt',
#  'David Quigley.txt',
#  'T.O.K.txt',
#  'Various Artists.txt',
#  'The Overtones.txt',
#  'Stefanie Schlesinger.txt',
#  'Jasmine Thompson.txt',
#  'Jesse Ed Davis.txt',
#  'Ray Fernandez.txt',
#  "Choir of King's College, Cambridge.txt",
#  "Da Youngsta's.txt",
#  '羅敏莊.txt',
#  'The Submarines.txt',
#  'Jaco Pastorius.txt',
#  'Octopus.txt',
#  'Boyhood.txt',
#  'New Ivory.txt',
#  'Aztec Camera.txt',
#  'Ray Miller.txt',
#  'Crippled Black Phoenix.txt',
#  'Pospieszalscy.txt',
#  'Brian Culbertson.txt',
#  'Black Star.txt',
#  'Uli Keuler.txt',
#  'The Vienna State Opera Orchestra.txt',
#  'Caribó.txt',
#  'The Del Lords.txt',
#  'Chor des Kölner Rundfunks, Orchester des Kölner Rundfunks, Ferdinand Leitner.txt',
#  'Siembra.txt',
#  'Darth&Vader vs. FTampa.txt',
#  'Empyre One vs. Energ!zer.txt',
#  'The Axis Of Perdition.txt',
#  'Kim English.txt',
#  'FISH GO DEEP.txt',
#  '5 Years And Counting.txt',
#  'Cole Swindell.txt',
#  'Rasmus Faber.txt',
#  'Kryder.txt',
#  'Manu Tenorio.txt',
#  'Oscar Salguero.txt',
#  'Yes.txt',
#  'HendriX.txt',
#  'Frankie Valli.txt',
#  'Ryszard Rynkowski.txt',
#  'Faultline.txt',
#  'JoJo.txt',
#  'Ray Scott.txt',
#  'The Electric Family.txt',
#  'Pinpoint.txt',
#  'White Canary.txt',
#  'Annie Haslam.txt',
#  'Atomic.txt',
#  'Lance Miller.txt',
#  'Dagmar Zsapkova-Sebestova.txt',
#  'Aril Brikha.txt',
#  'Wes Hampton.txt',
#  'Götz Alsmann.txt',
#  'Brandy.txt',
#  'July.txt',
#  'Paul Michiels.txt',
#  'Marc Bonilla.txt',
#  'Sick Feeling.txt',
#  'IRA.txt',
#  'Mr Oizo & Gaspard Augé.txt',
#  'Cosmo Klein.txt',
#  'Time Traveller.txt',
#  'Hank Williams.txt',
#  'Nevada.txt',
#  'Greedy Fingers.txt',
#  'Francesco Guccini.txt',
#  'Hiroyuki Iwaki.txt',
#  'The Ambition Company.txt',
#  'Simons.txt',
#  '汪明荃.txt',
#  'Jónsi & Alex.txt',
#  'Nine Days Wonder.txt',
#  'Doble Elefante.txt',
#  'Mustbeat Crew.txt',
#  'José Luis Encinas.txt',
#  'Akphaezya.txt',
#  'Glamrock Brothers.txt',
#  '60 Comptines Et Formulettes Pour Crèches.txt',
#  'Mr. President.txt',
#  'Paul Gant.txt',
#  'Deerhoof.txt',
#  'DJ Tune feat. Orremannen.txt',
#  'Sweet Sensation.txt',
#  'Joja Wendt & Les McCann.txt',
#  'Pod Buda.txt',
#  'Justine Electra.txt',
#  'Noel Sanger.txt',
#  'Sick Elektrik.txt',
#  "It's Like Love.txt",
#  'Shiny Toy Guns.txt',
#  'Susan Ebrahimi.txt',
#  'Silvio Carrano vs. Denmatt.txt',
#  'Bad Cash Quartet.txt',
#  'Bürdel King.txt',
#  'Jagoda.txt',
#  "Booker T. & the MG's.txt",
#  'Joel Hallikainen.txt',
#  'Mads Björn.txt',
#  'Arne Domnérus.txt',
#  'King Kong.txt',
#  'Schorsch H. & Dr. Will.txt',
#  'River City People.txt',
#  '45 Grave.txt',
#  'Olli Schulz.txt',
#  'Malurt.txt',
#  'Trentemøller.txt',
#  'Shirley Murdock.txt',
#  'Give em Blood.txt',
#  'Sugar Ray.txt',
#  'Defected Presents Most Rated Miami 2014.txt',
#  'Israel Vibration.txt',
#  'Jose Delgado.txt',
#  'Ray Noble.txt',
#  'Lúcio Alves.txt',
#  'Munich Allstars.txt',
#  'Time Gallery.txt',
#  'Paul Barbarin & His New Orleans Jazz Band.txt',
#  'Reuben Hoch And The RH Factor.txt',
#  'Juha Tapio.txt',
#  'Chet Baker, Wolfgang Lackerschmid.txt',
#  'Gyllene Tider.txt',
#  'Caramell.txt',
#  'TORI AMOS.txt',
#  'Temple City.txt',
#  'JESUS AND MARY CHAIN.txt',
#  'Roland Clarke.txt',
#  'Los Nativos.txt',
#  'Blake.txt',
#  'Alejandro Conde.txt',
#  'Ward 21.txt',
#  'Spinners.txt',
#  'Ghost Of A Fallen Age.txt',
#  'Mutiny Within.txt',
#  'Le Mur.txt',
#  'Akhénaton.txt',
#  'The Tailors.txt',
#  'BT.txt',
#  'I Grandi successi della Dance Italiana.txt',
#  'Fernando Saunders.txt',
#  'Stevie Ray Vaughn & Double Trouble.txt',
#  'Choeurs De Radio-Lyrique De La Rtf, Orchestre De Radio-Lyrique De La Rtf, Albert Wolf.txt',
#  'Swingfly.txt',
#  'Robert Bartha.txt',
#  'Rabbani WM.txt',
#  'Mikael Delta.txt',
#  'Michael Franks.txt',
#  'Crash.txt',
#  'Orchestre National De Barbès.txt',
#  'Victor Dinaire.txt',
#  'The Sounds.txt',
#  'LUKATHER & CARLTON.txt',
#  'Uwe Worlitzer feat. FAB.txt',
#  'Dan Tillberg.txt',
#  'Five Pointe O.txt',
#  'Tom Krause.txt',
#  'Grand High Priest.txt',
#  'Guy Johnston, R.S. Thomas.txt',
#  "Rockin' Robin & The Blue Jays.txt",
#  'Olivier Charlier, Jean Hubeau & Viotti Quartet.txt',
#  'Seductive.txt',
#  'Anne Hvidsten.txt',
#  'Angelit.txt',
#  'Robert Cray Band.txt',
#  'Keith Washington.txt',
#  'Seiji Ozawa.txt',
#  'George Huff.txt',
#  'Mark Eitzel.txt',
#  'Veronica Cossanteli.txt',
#  'Azari & III.txt',
#  'DCA Project.txt',
#  'Nacion Reixa.txt',
#  'Cinema.txt',
#  'Studiopunks.txt',
#  'Ultra Nate.txt',
#  'Kosmos.txt',
#  'Imperial Triumphant.txt',
#  'Devo.txt',
#  'Nathan Abshire & the Pine Grove Boys.txt',
#  'Essential Club Classics.txt',
#  'Ry Cooder.txt',
#  'Dino, Desi & Billy.txt',
#  "Pirates Of The Caribbean: Dead Man'S Chest.txt",
#  'Michael Teixeira.txt',
#  'The Musical Voices of Movies.txt',
#  'The Vision & Friends.txt',
#  'Seether.txt',
#  'Magnus Bäcklund.txt',
#  'Duo Bergerac.txt',
#  'Ennio Morricone.txt',
#  'Dude & Sweet.txt',
#  'Alexander Puschkin.txt',
#  'Five Years Lebensfreude 0.2.txt',
#  'Uno.txt',
#  'Prince Phillip Mitchell.txt',
#  'The Luyas.txt',
#  'Oh Land.txt',
#  'Sumera.txt',
#  'These Green Eyes.txt',
#  'Burgess & Slide.txt',
#  'Robson Miguel y grupo.txt',
#  'Daniela Dilow.txt',
#  'Bill Sims.txt',
#  'Clifters.txt',
#  'Luis Bacalov.txt',
#  'Caliban.txt',
#  'Michael Jackson Tribute.txt',
#  'Linval Thompson.txt',
#  'Pesch, Doro.txt',
#  'Tom Tom Club.txt',
#  'Coheed and Cambria.txt',
#  'Jacek Kaczmarski.txt',
#  'Sabine Kuegler.txt',
#  'Frische Brise & Kids.txt',
#  'B52.txt',
#  'Interface.txt',
#  'Menneisyyden vangit.txt',
#  'Junip.txt',
#  'Les 100 Plus Belles Chansons De Noël.txt',
#  'D At Sea.txt',
#  "beat 'n blow.txt",
#  'DumDum Boys.txt',
#  'Stacy.txt',
#  'Kelpe.txt',
#  'Karel Plihal.txt',
#  'Neumann.txt',
#  'Andrex.txt',
#  'Vassily Petrenko.txt',
#  'John Lill.txt',
#  "Here's My Number.txt",
#  'Van Hoick.txt',
#  'Choir of the Convent of Saint Elisabeth of Minsk.txt',
#  'Venus Kaly.txt',
#  'A.KOR.txt',
#  'Luis Francesco Arena.txt',
#  'Miguel Migs.txt',
#  'Sleepytime Gorilla Museum.txt',
#  'Mathieu Bouthier & Muttonheads.txt',
#  'The Dance Party.txt',
#  'Johan Gielen.txt',
#  'DJ Kayz.txt',
#  'Twilight Ophera.txt',
#  'Münchner Saitentratzer.txt',
#  'Scott Bradlee & Postmodern Jukebox.txt',
#  'Iwaro.txt',
#  'Al Jarreau.txt',
#  'Don Edwards.txt',
#  'Jimmy Rogers.txt',
#  'Kris Wadsworth.txt',
#  'Jane Glover.txt',
#  'Wayne Wonder & Sanchez.txt',
#  'Charlie Palmieri.txt',
#  'Speedy Ortiz.txt',
#  'T.Love.txt',
#  'The Valentines.txt',
#  'Rob Mayth.txt',
#  'Riddim Driven: My Swing.txt',
#  'Marasco.txt',
#  'Yutaka Sado & Orchestre Philharmonique de Radio France.txt',
#  'Various Artists - Death Before Distemper.txt',
#  'Alberto Bologni & Christopher Howell.txt',
#  'Elin Ruth Sigvardsson.txt',
#  '84.txt',
#  'Acetronik.txt',
#  'Shook Ones.txt',
#  'Gerald Albright.txt',
#  'ZooFunktion.txt',
#  'Pajama Party.txt',
#  'Sutekh, Safety Scissors.txt',
#  "Juan d'Arienzo.txt",
#  'The Delltones.txt',
#  'Aretha Franklin & Sam Cooke.txt',
#  'Tristania.txt',
#  'Goodbye Jersey.txt',
#  'Gwyllion.txt',
#  'Toy Matinee.txt',
#  'Groupies bleiben nicht zum Frühstück.txt',
#  'The Tämmel Quartet.txt',
#  'LuuX.txt',
#  'Theo Olof.txt',
#  'Ayberk Efendi and the Naqshi-Band.txt',
#  'Sirion.txt',
#  'Dame Edith Evans.txt',
#  'Harmonizer.txt',
#  'Rudolf Kempe.txt',
#  'Georges Chelon.txt',
#  'Tomas Jirku, Robin Judge.txt',
#  'Die Kinder Hörspiel Erzähler.txt',
#  'The Treorchy Male Voice Choir.txt',
#  'Brain Police.txt',
#  'Milt Jackson & John Coltrane.txt',
#  'Daniel Tosh.txt',
#  'Flowers Forever.txt',
#  'Hans-Jörg Wegner, Christiane Kroeker.txt',
#  'Pawel Kukiz.txt',
#  'Mnozil Brass.txt',
#  'Luis Vazquez.txt',
#  'Craig Campbell.txt',
#  'The Rockhouse Brothers.txt',
#  'Come The Dawn.txt',
#  'Romántico Latino.txt',
#  'Micranots.txt',
#  'Silvius Sonvilla.txt',
#  'Lethal Rockerz feat. Adiam.txt',
#  'Copyright Feat Imaani.txt',
#  'The Postmarks.txt',
#  'Dana Bryant.txt',
#  'Albertucho.txt',
#  'Joe Turner.txt',
#  'Efstathia.txt',
#  'The Disco Biscuits.txt',
#  'Various Artists - 100 Garage Classics.txt',
#  'Endrick Brothers.txt',
#  'Hubert Laws.txt',
#  'Beth Hirsch.txt',
#  'Reino Helismaa.txt',
#  'Alfredo Simonetto.txt',
#  'Anthony Rolfe Johnson.txt',
#  'Daniel Luna.txt',
#  'Otis Redding.txt',
#  'Arbeid Adelt!.txt',
#  'George Fenton.txt',
#  'Sheldon Blackman.txt',
#  'Take A Look.txt',
#  'Nerina Pallot.txt',
#  'The Mission District.txt',
#  'Erik Grip.txt',
#  'Barbara Andreini e Gabriele Antonelli.txt',
#  'King Missile.txt',
#  'Los Morenos.txt',
#  'Prince Far I.txt',
#  'BoDeans.txt',
#  'Shampoo.txt',
#  'Howard Tate.txt',
#  'Sam Means.txt',
#  'The Aloof.txt',
#  'John Sinclair.txt',
#  'Loka.txt',
#  'Steel Pulse.txt',
#  'H16.txt',
#  'Bixel Boys.txt',
#  'Anzhelika Nachesova.txt',
#  'Gerard Low.txt',
#  'Trio Daphnis.txt',
#  'MURANO meets TOKA.txt',
#  'Thaitanium Entertainment.txt',
#  'Fiuk.txt',
#  'Volta Bureau.txt',
#  'Stephen Sondheim.txt',
#  'Sluts on Electro.txt',
#  'Barratt Waugh.txt',
#  'The Downtown Fiction.txt',
#  'DBN.txt',
#  'Wookie feat. Lain.txt',
#  'Innata.txt',
#  'Krzysztof Scieranski.txt',
#  'Billy Cobham & Glassmenagerie.txt',
#  'DJ Denny Gee vs. Beat4Port.txt',
#  'Robin B..txt',
#  'Olive.txt',
#  'Daniel Verdun.txt',
#  'Carla Bley.txt',
#  'Drenge.txt',
#  'True Lies.txt',
#  'Jean Agoriia.txt',
#  'Phil Jones & The Unknown Blues.txt',
#  'Covered, A Revolution in Sound: Warner Bros. Records.txt',
#  'N8N (Nathan).txt',
#  'Stiff Little Fingers.txt',
#  'BMP-Music.txt',
#  'Emilia.txt',
#  'Dionne Warwick.txt',
#  'Nacho Mañó y Gisela Renes.txt',
#  'Manian feat. aila.txt',
#  'Wilmoth Houdini.txt',
#  'Esser.txt',
#  'Trine Rein.txt',
#  'Radio Futura.txt',
#  'Ronin.txt',
#  'Petronelli & Angel D.txt',
#  'Marino Manferdini und Fricktaler Muulörgelitrio.txt',
#  'Melissa Steel.txt',
#  'Steal Vybe presents.txt',
#  'Dent May.txt',
#  'Dik Lewis.txt',
#  'Greenleaf.txt',
#  'Mr. Review.txt',
#  'Collins, Simon.txt',
#  'Die Antwort.txt',
#  'Sunchild.txt',
#  'Candela.txt',
#  'Stereos.txt',
#  'Dia Fadila.txt',
#  'Intelligent Manners.txt',
#  'Fazura.txt',
#  'Stefan Schill.txt',
#  'Shane Harper.txt',
#  'ROGER GLOVER.txt',
#  'Liederjan.txt',
#  'Andrzej Bachleda.txt',
#  'Timothy B. Schmit.txt',
#  'ERIC SARDINAS.txt',
#  'The Milestones.txt',
#  'Meiju Suvas.txt',
#  'E-Smoove.txt',
#  'Wire.txt',
#  'Lost & Found EP.txt',
#  'Alex North, Jerry Goldsmith, The National Philharmonic Orchestra.txt',
#  'DJ Space Raven vs Wavetraxx.txt',
#  'DJ Wag.txt',
#  'Larry Graham.txt',
#  'Daniel Barenboim & Orchestre de Paris.txt',
#  'Cleptomanics.txt',
#  'Jidax.txt',
#  'The Cribs.txt',
#  'Hamburger Ratsmusik Ensemble für alte Musik.txt',
#  'Aleksa.txt',
#  'The Legacy.txt',
#  'Mischa Maisky.txt',
#  'Small Sur.txt',
#  'Roskildekoret m. Merete Hjortsø, Guido Paëvatalu, Christian Christiansen og Niels Henrik Nielsen.txt',
#  'Andreas Lundstedt.txt',
#  'Dave Grusin.txt',
#  'Madonna Hip Hop Massaker.txt',
#  'Laura Närhi.txt',
#  'Eduard Stan.txt',
#  'Karel Svoboda.txt',
#  'Thaitanium.txt',
#  'Dustin Henze And The Dreamer.txt',
#  'Du Pacque.txt',
#  'Nova Mob.txt',
#  'Mercury.txt',
#  'Pablo Kopanos.txt',
#  'deadmau5.txt',
#  'Matthew Styles.txt',
#  'Grace.txt',
#  'Rosa Fra Rouladegade.txt',
#  'Hans Christian Andersen.txt',
#  'Aborym.txt',
#  'Jacks Of All Trades.txt',
#  'András Schiff.txt',
#  'Ryan Thistlebeck vs. Rainy.txt',
#  'Suicidal Tendencies.txt',
#  'Sister Hazel.txt',
#  'Münchener Freiheit.txt',
#  'Hull.txt',
#  'Piazzolla, Astor: Kremer, Gidon.txt',
#  'Haswell & Hecker.txt',
#  'Larry Carlton.txt',
#  'The Secret of N.I.M.H..txt',
#  'Marcel Azzola et son ensemble musette.txt',
#  'Jan Wayne vs. RainDropz!.txt',
#  'Pedro Iturralde.txt',
#  'Flowin Immo et Les Freaqz.txt',
#  'Balde Gonzalez.txt',
#  'Odette Toulemonde.txt',
#  'Further Seems Forever.txt',
#  'Fischer Choere.txt',
#  'Map Of The World At Night.txt',
#  'Step Brothers.txt',
#  'Felicity Lott.txt',
#  'Jean-Pierre Rampal, Claudio Scimone & I Solisti Veneti.txt',
#  'Bridgestone.txt',
#  'Italoboyz vs. Blind Minded.txt',
#  'Ini Kamoze.txt',
#  'Georg Walther.txt',
#  'Misery Signals.txt',
#  'The Ocean.txt',
#  'Cute Is What We Aim For.txt',
#  'Devendra Banhart.txt',
#  'Killing Paparazzi & Jose Gran Color.txt',
#  'Moon Boots.txt',
#  'Horna.txt',
#  'Mark Benecke.txt',
#  'Regi.txt',
#  'Juan Kidd.txt',
#  'Will Crawshaw.txt',
#  'Timo Lassy.txt',
#  'Bellepop.txt',
#  'Bad Brains.txt',
#  'Benjiy.txt',
#  'Henry Mancini.txt',
#  'Lucy Woodward.txt',
#  'Christian McBride.txt',
#  'Psarantonis.txt',
#  'NESSI.txt',
#  'XXY.txt',
#  'Marius Jung.txt',
#  'Fabian Reichelt.txt',
#  'DJ Sneak.txt',
#  'Sergio Contreras.txt',
#  'The Pepper Pots.txt',
#  'Dharkfunkh.txt',
#  'Original London Cast.txt',
#  'Kalevi Olli and Ulrich Koneffke.txt',
#  'DJ Scream.txt',
#  "Siyou'n'Hell.txt",
#  'Trescem.txt',
#  'Anemos.txt',
#  'Nuova Compagnia di Canto Popolare.txt',
#  'Frank Wright Sextet.txt',
#  'D-Tune vs. Sunics, V.I.D.´s.txt',
#  'B.A.D..txt',
#  'Chad Brock.txt',
#  'Säwes.txt',
#  'Kasie Sharp.txt',
#  'Jeremy Aggers.txt',
#  'Fabienne.txt',
#  'Linda Mirada.txt',
#  'The Paul Butterfield Blues Band.txt',
#  'Ville Valo & Natalia Avelon.txt',
#  'The Gadflys.txt',
#  'Dany Silva.txt',
#  'Morgan Page.txt',
#  'Heidi Montag.txt',
#  'JD Souther.txt',
#  'Superchumbo.txt',
#  'GoThinkBig.txt',
#  'Pin.txt',
#  'Radical Face.txt',
#  'Lord Of The Rings 3-The Return Of The King.txt',
#  'Wille Crafoord.txt',
#  'Sort Sol.txt',
#  'Palisades.txt',
#  'Luis Mariano.txt',
#  'Lionel Handy & Nigel Clayton.txt',
#  'Mandalay Ambient Orchestra.txt',
#  'Lucha Villa.txt',
#  'Soul Clan.txt',
#  'Viola.txt',
#  'Xuefei Yang.txt',
#  'Jesse Garcia & Peter Gelderblom.txt',
#  'Anton Karas.txt',
#  'Nina Martinique.txt',
#  'Coro De Jerez.txt',
#  'John Oszajca.txt',
#  'Joyce Jonathan.txt',
#  'Youngblood.txt',
#  'Victoria Duffield.txt',
#  'Greenslade.txt',
#  'Yakka.txt',
#  'Hadouken! Not Here To Please You.txt',
#  'Dub Tribe Sound System.txt',
#  'Mavericks.txt',
#  'Sir Alexander Gibson.txt',
#  'Oncle Strongle.txt',
#  'Salvatore Stars.txt',
#  'IAMLOPEZ.txt',
#  'Baden Baden.txt',
#  'Rigu.txt',
#  'Coal Chamber.txt',
#  'The Blow.txt',
#  'Dioni Martín.txt',
#  'David Oleart.txt',
#  'Ella.txt',
#  'French Tobacco.txt',
#  'Constance Verluca.txt',
#  'Los Broncos de Reynosa.txt',
#  'Busy Bee.txt',
#  'Kirsten Flagstad.txt',
#  'Conjunto Alma Jarocha.txt',
#  "Lil' Mo Yin Yang.txt",
#  'Robin Lane & The Chartbusters.txt',
#  'Crescent Moon Is In Big Trouble.txt',
#  'Lepo Sumera.txt',
#  '張峽浩.txt',
#  'Maxim Vengerov, Zubin Mehta & Israel Philharmonic Orchestra.txt',
#  'Peter White.txt',
#  'the JaneDear girls.txt',
#  'Heartless Bastards.txt',
#  'Demuja.txt',
#  'Jeannine Otis.txt',
#  'Rolando Villazon.txt',
#  'Singing Melody.txt',
#  'Pon de Rockaz.txt',
#  'ACO.txt',
#  'Spacelab.txt',
#  'Show Of Hands.txt',
#  'Infernal Overdrive.txt',
#  'Top of the Pops: 1994 Bitesize - EP.txt',
#  'Hania Stach.txt',
#  'Maja Sikorowska.txt',
#  'Racine.txt',
#  'Disco Globe Inc..txt',
#  'Angels And Demons.txt',
#  "Lee 'Scratch' Perry.txt",
#  'Bente Lind.txt',
#  'Tommys.txt',
#  'Groove Da Praia.txt',
#  'Sangit.txt',
#  'Tacabro.txt',
#  'Sumner.txt',
#  'Carlos Mencia.txt',
#  'Dezza.txt',
#  'Breakfast On Pluto.txt',
#  'Rick Vito.txt',
#  'The Knife.txt',
#  'KitSch Crew.txt',
#  'Binocular.txt',
#  'Narval.txt',
#  'Search For the Soul.txt',
#  'Hothouse Flowers.txt',
#  'Sneakers.txt',
#  'Sixx:A.M..txt',
#  'Radio Killer.txt',
#  'Ethan Hawke.txt',
#  'The Freedom Sounds.txt',
#  'Noir & Hayze.txt',
#  'The Time.txt',
#  'Gibby Haynes and His Problem.txt',
#  "Jus'Dope.txt",
#  'Gerling.txt',
#  'Neymar Song.txt',
#  'Steve H.txt',
#  'Margo.txt',
#  'Clive Williamson.txt',
#  'Arianna Puello.txt',
#  'Elaine Paige.txt',
#  'Wolfgang Muthspiel & Mick Goodrick.txt',
#  'Hunter Hayes.txt',
#  'Laika & The Cosmonauts.txt',
#  'Martin Schmitt.txt',
#  'Jordan Baird.txt',
#  'Gregor McEwan.txt',
#  '天天.txt',
#  'Edward Aldwell.txt',
#  'Nik & Jay.txt',
#  'Thich Nhat Hanh.txt',
#  'Joe Rogan.txt',
#  'Superfreakz.txt',
#  'Flavio Rodriguez.txt',
#  'Doveman.txt',
#  'Iveta Bartosova.txt',
#  'Someday Jacob.txt',
#  'Cliff Jackson.txt',
#  'Vivax.txt',
#  'Chris Deshield.txt',
#  'Diederik Suys.txt',
#  'Hot Rod Circuit.txt',
#  'Göran Lindbergs Orkester.txt',
#  'Mark Kilian & Paul Hepker.txt',
#  'Marco Allevi.txt',
#  'Shirley Scott.txt',
#  'Billy Joe Shaver.txt',
#  'Zubin Mehta.txt',
#  'Suso Saiz.txt',
#  'Stephanie K..txt',
#  'Happiness.txt',
#  'Emma Salokoski Ensemble.txt',
#  'Elizabeth McGovern.txt',
#  'Chris Spedding.txt',
#  'Belinda Carlisle.txt',
#  'RL Grime.txt',
#  'Fruela.txt',
#  'Heathen Foray.txt',
#  'Jimmy Little.txt',
#  "Orchestra della Radio di Bratislava, Coro del Teatro dell' Opera di Bratislava, Edoardo Brizio.txt",
#  'The Donkeys.txt',
#  'Rich Kids.txt',
#  'Lawrence.txt',
#  'September.txt',
#  'Billy J Kramer.txt',
#  'Pusssssy Galore.txt',
#  'Arash.txt',
#  'Powermix FM Radio.txt',
#  'Clubsequenzer.txt',
#  'Catcat.txt',
#  'Raúl Abril.txt',
#  'Der Prophet.txt',
#  'Daath.txt',
#  'I See Stars.txt',
#  'Reverendo Moe.txt',
#  'Brothers From Another Planet.txt',
#  'Ensemble Caprice.txt',
#  'Cristal Snow.txt',
#  'Jason Isbell.txt',
#  'Alt Schuss.txt',
#  'Little Louie Vega & Marc Anthony.txt',
#  'Mase.txt',
#  'Air Supply.txt',
#  'Bruno.txt',
#  'Maite Kelly.txt',
#  'El Chavo Animado.txt',
#  'I Speak Machine.txt',
#  'Sona Fariq.txt',
#  'DeeLectro meets Brandox.txt',
#  'Alis Dee.txt',
#  'Theatres Des Vampires.txt',
#  'Lampert.txt',
#  'Beata.txt',
#  'Scooby-Doo 2: Monsters Unleashed.txt',
#  'DJ Elephant Power.txt',
#  'Subterranean Masquerade.txt',
#  'Local H.txt',
#  'The Associates.txt',
#  'Andreas Staier.txt',
#  'Marionetz.txt',
#  'Angel.txt',
#  'Willem Mengelberg & Royal Concertgebouw Orchestra.txt',
#  'LTj.txt',
#  'Yuri Temirkanov & St Petersburg Philharmonic Orchestra.txt',
#  'Sandy Lopicic Orchestar.txt',
#  'Jacob Groth.txt',
#  'Fredrik Vahle.txt',
#  'Shiga Lin.txt',
#  'Fireball Ministry.txt',
#  'Brigitte Angerhausen.txt',
#  'Neon Neon.txt',
#  'The Adventures.txt',
#  'Mathias Schaffhäuser.txt',
#  'Berk & The Virtual Band.txt',
#  'Rossington.txt',
#  'Jowell & Randy.txt',
#  'Roben Og Knud.txt',
#  'Gary Louris.txt',
#  'Botz & Flydrums vs. Danny Villa.txt',
#  'Candeia.txt',
#  "Maliq & d'Essentials.txt",
#  'Marc Copland & Dieter Ilg with Ralph Penland.txt',
#  'Azucar Moreno.txt',
#  'Glez..txt',
#  'Bob van Asperen.txt',
#  'Otto Klemperer.txt',
#  'Sumpens Swingsters.txt',
#  'Björn Alke Quartet.txt',
#  'COHEN.txt',
#  'Charlie Shavers.txt',
#  'Anneleen Lenaerts.txt',
#  'Tomas Barfod.txt',
#  'LoSoul.txt',
#  'Stephan Möller.txt',
#  'Home.txt',
#  'Santino.txt',
#  "That's Outrageous!.txt",
#  'Matt Pond PA.txt',
#  'Mychael Danna.txt',
#  'Jan Böhmermann.txt',
#  'TED NUGENT.txt',
#  'DJ Able.txt',
#  'Las seventies.txt',
#  "De Romeo's.txt",
#  "Sunday's Best.txt",
#  'Moreira Da Silva.txt',
#  'The Choristes Les Petits Chanteurs De Saint Marc.txt',
#  'Mel & Kim.txt',
#  'Cassey Doreen.txt',
#  'Paul Jones.txt',
#  'Tong.txt',
#  'Boris Berezovsky, Dmitri Liss & Ural Philharmonic Orchestra.txt',
#  'Piotr Anderszewski.txt',
#  'Art Of Tones.txt',
#  'Jazz K Lipa.txt',
#  'Oliver Frank.txt',
#  'Lazee.txt',
#  'TFDI.txt',
#  'Pierre Van Dormael, Hervé Samb.txt',
#  'Deekline & Tim Healey.txt',
#  'Atlantic Fusion.txt',
#  'Martin Lawrence.txt',
#  'Sabaton.txt',
#  '王矜霖.txt',
#  'Powerface.txt',
#  'Deborah Campbell Band.txt',
#  'Freddie McGregor.txt',
#  'ARTES.txt',
#  'Peter Holsapple & Chris Stamey.txt',
#  'GEORGE CLINTON.txt',
#  'The Ditty Bops.txt',
#  "Uberjak'd.txt",
#  'Eini.txt',
#  'Melissa Indot.txt',
#  'Gordon Haskell.txt',
#  'Dick Ray.txt',
#  'Ibo.txt',
#  'Cheikha Rimitti.txt',
#  'Männerchor Aichschiess.txt',
#  'Tangolectrón.txt',
#  'DERANGED.txt',
#  'Frank Schöbel.txt',
#  'Kissogram.txt',
#  'Mansun.txt',
#  'Santiago Jimenez Jr..txt',
#  'Stafford Brothers.txt',
#  'Lenni-Kalle Taipale.txt',
#  'Orquesta mondragon.txt',
#  'Saille.txt',
#  'Kake Randelin.txt',
#  'Irmãs Galvão.txt',
#  'Ray Stevens.txt',
#  'Malecón & Chandelier RC.txt',
#  'The Session ปรากฏการณ์ดนตรี 11 มกราคม 2556.txt',
#  'Drvg Cvltvre.txt',
#  'Cyan.txt',
#  'Page McConnell.txt',
#  'banvox.txt',
#  'มนต์ เพลง คาราบาว.txt',
#  'Brinsley Schwarz.txt',
#  'Lee Ritenour.txt',
#  'For Fuld Musik - 25 Danske Sommer Pop & Rock Hits Vol. 1.txt',
#  'Runa.txt',
#  'Make Believe Me.txt',
#  'Piper Records.txt',
#  'Sasha.txt',
#  'Hannes Staffler.txt',
#  'Ahlberg, Ek & Roswall.txt',
#  'Ramatam.txt',
#  'Aischa Traidia.txt',
#  '21 Japonesas.txt',
#  'Ravi Shankar.txt',
#  'Denroy Morgan.txt',
#  'Northlane.txt',
#  'Riddim of Zion-Ras Benji.txt',
#  'Ralf Eugen Barttenbach.txt',
#  'Troy Brown.txt',
#  'Third Eye Blind.txt',
#  'Susan James.txt',
#  'Flamingo Star.txt',
#  'Black Fire.txt',
#  'Pablo Abraira.txt',
#  'SECRETS.txt',
#  'General Chaos.txt',
#  'Bernard Soustrot & Jean Dekyndt.txt',
#  'Les Jumo.txt',
#  'Hopeton Lindo.txt',
#  'Sorgenkind.txt',
#  'The Chelsea Pensioners.txt',
#  'Chisu.txt',
#  'The SilverBacks.txt',
#  'Cassie Taylor.txt',
#  'J. Peter Robinson.txt',
#  'Tetu Bernard.txt',
#  'Wellental.txt',
#  'Estra.txt',
#  'T. Power.txt',
#  'Blur.txt',
#  'Callahan.txt',
#  'Wanda Walden.txt',
#  'Champion Jack Dupree.txt',
#  'Alekos Vretos.txt',
#  'Jamal Abdillah.txt',
#  'Life Sounds Nature.txt',
#  'Emmanuel Rambaldi.txt',
#  'Catherine.txt',
#  'DJ Infinite.txt',
#  'Billy Eckstine.txt',
#  'Faces.txt',
#  'Atmosphere.txt',
#  'Tapio Heinonen.txt',
#  'The History Boys Original Soundtrack.txt',
#  'Christiane F..txt',
#  'เจนนิเฟอร์ คิ้ม.txt',
#  'Rastatter Jugendchor, Rudi Kühn.txt',
#  'Tiffany.txt',
#  'Zoe Beck.txt',
#  'Lena Conradson.txt',
#  'Alexandre Desplat.txt',
#  'State Radio.txt',
#  'Baseball A Film By Ken Burns.txt',
#  'Loaded Dice.txt',
#  'Doomstarks.txt',
#  'Lazaro Casanova.txt',
#  'Tango for Four.txt',
#  'Normaal.txt',
#  'Ensemble Sarband.txt',
#  'Shel Silverstein.txt',
#  'Jackson Browne & David Lindley.txt',
#  'Kaci Battaglia.txt',
#  'Maria Thalita de Paula.txt',
#  'John Martyn.txt',
#  'Mike Fender.txt',
#  'Rex Nelon Singers.txt',
#  'DiscoRocks.txt',
#  'The Wildhearts.txt',
#  'Fish.txt',
#  'Johnny Smith.txt',
#  'Josey Wales & Charlie Chaplin.txt',
#  'Vltava.txt',
#  "Boys of King's College Choir, Cambridge.txt",
#  'Do Me Bad Things.txt',
#  'Reset Safari.txt',
#  'Tiger And Dragon.txt',
#  'With Honors.txt',
#  'Pipes.txt',
#  'Obe Dve.txt',
#  'Richard Blackwood.txt',
#  'Mobnoiz.txt',
#  'Ana Pozas.txt',
#  'Will Hoge.txt',
#  'Michael B Tretow.txt',
#  'Sir Malcolm Sargent.txt',
#  'Ride.txt',
#  'Hollywood 2011 Film Classics.txt',
#  'Sister Sledge.txt',
#  'BOB CARPENTER.txt',
#  'Antonio Vega.txt',
#  'The Magnetic Fields.txt',
#  'Candy Dulfer.txt',
#  'Norddeutscher Figuralchor, Jörg Straube.txt',
#  'Hans Zimmer.txt',
#  'Shack.txt',
#  'Max Lyazgin.txt',
#  'Dj Suraci And Spins.txt',
#  'Chor der Metropolitan Opera, Orchester der Metropolitan Opera.txt',
#  'Buddy Holly.txt',
#  'Chonda Pierce.txt',
#  'Eddie Kendricks.txt',
#  'Coretta Scott.txt',
#  'Thomas Zehetmair, Deutsche Kammerphilharmonie, Philharmonia Orchestra & Heinz Holliger.txt',
#  'Dusty Trails.txt',
#  'Vitacit.txt',
#  'Bernard Herrmann, Joel McNeely, Royal Scottish National Orchestra.txt',
#  'Stéphane Grappelli.txt',
#  'Toy Love.txt',
#  '羅文.txt',
#  'The Invincible Spirit.txt',
#  'Ella Fuksbrauner.txt',
#  "Treble 'N Bass.txt",
#  'Beto Barbosa.txt',
#  'Son of Noise.txt',
#  'Bonaparte.txt',
#  'Afterlife feat. Cathy Battistessa.txt',
#  'Mamadou Diouf.txt',
#  'Top of the Pops: 1970 Bitesize - EP.txt',
#  'Back Street Crawler.txt',
#  'R&B Christmas.txt',
#  'Jussi & The Boys.txt',
#  'Interactive.txt',
#  'Koblizc!.txt',
#  'Superfjord.txt',
#  'Cantabile.txt',
#  ...]

# %%
aaa
# Out:
# ['Various Artists.txt',
#  'Coldplay.txt',
#  'Clean Bandit.txt',
#  'Ed Sheeran.txt',
#  'David Guetta.txt',
#  'Dennis Brown.txt']

# %%
import sys
sys.getsizeof(rank)
# Out:
# 168

# %%
['Various Artists.txt',
 'Coldplay.txt',
 'Clean Bandit.txt',
 'Ed Sheeran.txt',
 'David Guetta.txt',
 'Dennis Brown.txt']
